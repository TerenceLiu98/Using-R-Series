# %%
x <- c(1,3,5,5.5,6,6.2,6.6,7,7.3,7.5,8,10)

# %%
density(x)
# Out:
# Call:
# 	density.default(x = x)
#
# Data: x (12 obs.);	Bandwidth 'bw' = 0.807
#
#        x                y
#  Min.   :-1.421   Min.   :0.0004633
#  1st Qu.: 2.040   1st Qu.:0.0286405
#  Median : 5.500   Median :0.0442339
#  Mean   : 5.500   Mean   :0.0721581
#  3rd Qu.: 8.960   3rd Qu.:0.1034239
#  Max.   :12.421   Max.   :0.2275802

# %%
plot(density(x))
# Out:
# Plot with title “density.default(x = x)”
